# %% [markdown]
# Presentar el tipo de dato de cadena

# %%
myString= "This is a string"

print(f"{myString} is of the data type {type(myString)}")
# Out:
# This is a string is of the data type <class 'str'>

# %% [markdown]
# Trabajar con concatenación de cadenas

# %%
firstString = "water"
secondString = "fall"
thirdString = firstString + secondString

print(thirdString)
# Out:
# waterfall

# %% [markdown]
# Trabajar con cadenas de entrada

# %%
name = input("What is your name? "
             )
print(f"Hola {name}")
# Out:
# Hola Leo

# %% [markdown]
# Dar formato a las cadenas de salida

# %%
color = input("Cuál es tu color favorito?  ")
animal = input("Cuál es tu animal favorito?  ")

print("{}, te gusta un {} {}!".format(name,color,animal))
# Out:
# Leo, te gusta un verde león!
